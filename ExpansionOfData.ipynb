# %%
pip install pandas sklearn sportsreference
# Out:
# ...
#      |████████████████████████████████| 472 kB 3.2 MB/s
# ...

# %%
from sportsreference.ncaab.teams import Teams

# %%
list_of_teams = Teams()

# %%
team_schedules = {}
for team in list_of_teams:
    schedule = team.schedule  # Returns a Schedule instance for each team
    # Returns a Pandas DataFrame of all metrics for all game Boxscores for
    # a season.
    team_schedules[team.name] = schedule

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !rm -rf content/

# %%
for key, value in team_schedules.items():
  team_title = key
  value.dataframe.to_csv(r'/content/gdrive/MyDrive/Capstone Project/2022Data/{}.csv'.format(team_title),index=False)

# %%
# !zip -r /content/file.zip /content/
# Out:
# zip error: Interrupted (aborting)

# %%
from google.colab import files
for team in list_of_teams:
  files.download(f'{team.name}.csv')
